# %% [markdown]
# # EDA on Fitbit Fitness Tracker Data

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing the required csv file
file_path= r'C:\Users\vishn\Desktop\Anaconda\GitHub\Fitbit Dataset\dailyActivity_merged_cleaned.csv'
df= pd.read_csv(file_path)

# %%
# Dataframe
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1624580081   2016-05-01       36019      28.030001        28.030001
# 1    1644430081   2016-04-14       11037       8.020000         8.020000
# 2    1644430081   2016-04-19       11256       8.180000         8.180000
# 3    1644430081   2016-04-28        9405       6.840000         6.840000
# 4    1644430081   2016-04-30       18213      13.240000        13.240000
# ..          ...          ...         ...            ...              ...
# 935  1844505072   2016-04-20           8       0.010000         0.010000
# 936  4020332650   2016-04-17          16       0.010000         0.010000
# 937  4319703577   2016-05-12          17       0.010000         0.010000
# 938  6775888955   2016-05-03           9       0.010000         0.010000
# 939  7086361926   2016-04-16          31       0.010000         0.010000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
# To check the count of null values and data types of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        940 non-null    int64
#  1   ActivityDate              940 non-null    object
#  2   TotalSteps                940 non-null    int64
#  3   TotalDistance             940 non-null    float64
#  4   TrackerDistance           940 non-null    float64
#  5   LoggedActivitiesDistance  940 non-null    float64
#  6   VeryActiveDistance        940 non-null    float64
#  7   ModeratelyActiveDistance  940 non-null    float64
#  8   LightActiveDistance       940 non-null    float64
#  9   SedentaryActiveDistance   940 non-null    float64
#  10  VeryActiveMinutes         940 non-null    int64
#  11  FairlyActiveMinutes       940 non-null    int64
#  12  LightlyActiveMinutes      940 non-null    int64
# ...

# %%
# Create a DataFrame without the Id column 
data_subset = df.drop(columns=['Id'])

# %%
# The correlation of the dataset
plt.figure(figsize=(10, 8))
sns.heatmap(data_subset.corr(), annot=True, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_4616\3033451631.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_subset.corr(), annot=True, linewidths=0.5)

# %%
# Dividing the dataset for detailed summary statistics
stats1= ['TotalSteps', 'TotalDistance', 'TrackerDistance', 'LoggedActivitiesDistance','Calories']
stats2= ['TotalSteps', 'TotalDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 'Calories']
stats3= ['TotalSteps', 'TotalDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

# %%
# To generate the summary statistics for a subset of data
s1= df[stats1].describe()
s1
# Out:
#          TotalSteps  TotalDistance  TrackerDistance  LoggedActivitiesDistance  \
# count    940.000000     940.000000       940.000000                940.000000
# mean    7637.910638       5.489702         5.475351                  0.108171
# std     5087.150742       3.924606         3.907276                  0.619897
# min        0.000000       0.000000         0.000000                  0.000000
# 25%     3789.750000       2.620000         2.620000                  0.000000
# 50%     7405.500000       5.245000         5.245000                  0.000000
# 75%    10727.000000       7.712500         7.710000                  0.000000
# max    36019.000000      28.030001        28.030001                  4.942142
#
#           Calories
# count   940.000000
# mean   2303.609574
# std     718.166862
# min       0.000000
# 25%    1828.500000
# 50%    2134.000000
# 75%    2793.250000
# max    4900.000000

# %%
# To generate the summary statistics for a subset of data
s2= df[stats2].describe()
s2
# Out:
#          TotalSteps  TotalDistance  VeryActiveDistance  \
# count    940.000000     940.000000          940.000000
# mean    7637.910638       5.489702            1.502681
# std     5087.150742       3.924606            2.658941
# min        0.000000       0.000000            0.000000
# 25%     3789.750000       2.620000            0.000000
# 50%     7405.500000       5.245000            0.210000
# 75%    10727.000000       7.712500            2.052500
# max    36019.000000      28.030001           21.920000
#
#        ModeratelyActiveDistance  LightActiveDistance  SedentaryActiveDistance  \
# count                940.000000           940.000000               940.000000
# mean                   0.567543             3.340819                 0.001606
# std                    0.883580             2.040655                 0.007346
# min                    0.000000             0.000000                 0.000000
# ...

# %%
# To generate the summary statistics for a subset of data
s3= df[stats3].describe()
s3
# Out:
#          TotalSteps  TotalDistance  VeryActiveMinutes  FairlyActiveMinutes  \
# count    940.000000     940.000000         940.000000           940.000000
# mean    7637.910638       5.489702          21.164894            13.564894
# std     5087.150742       3.924606          32.844803            19.987404
# min        0.000000       0.000000           0.000000             0.000000
# 25%     3789.750000       2.620000           0.000000             0.000000
# 50%     7405.500000       5.245000           4.000000             6.000000
# 75%    10727.000000       7.712500          32.000000            19.000000
# max    36019.000000      28.030001         210.000000           143.000000
#
#        LightlyActiveMinutes  SedentaryMinutes     Calories
# count            940.000000        940.000000   940.000000
# mean             192.812766        991.210638  2303.609574
# std              109.174700        301.267437   718.166862
# ...

# %%
# To sort the DataFrame by ActivityDate
df_sorted = df.sort_values(by='ActivityDate')

# Plot of the mean total steps per day
ax = df_sorted.groupby(df_sorted['ActivityDate']).aggregate({'TotalSteps':'mean'}).plot(figsize=(17,8))
ax.set_title('Total Steps per Day')
ax.set_xlabel('Date')
ax.set_ylabel('Mean Total Steps')
ax.grid(True)

# To get all unique dates from the sorted DataFrame
unique_dates = df_sorted['ActivityDate'].unique()

# Set the x-axis tick locations and labels
ax.set_xticks(range(len(unique_dates)))
ax.set_xticklabels(unique_dates, rotation=45)  # Rotate and align date labels for better readability

plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
# Plot of the mean od Calories burnt to the distance recorded by Tracker
df.groupby(df['TrackerDistance']).aggregate({'Calories':'mean'}).plot(figsize=(15,7))
plt.title('Calories vs Tracker Distance')
plt.xlabel('Tracker Distance (in miles)')
plt.ylabel('Calories')
plt.grid(True)
plt.show()

# %%
# Plot of Calories burned to the Total Steps
plt.figure(figsize=(15,7))
plt.scatter(df['TotalSteps'], df['Calories'])
plt.title('Calories vs Total Steps')
plt.xlabel('Total Steps')
plt.ylabel('Calories')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
# Plot of Very Active Minutes to the Calories burned
plt.figure(figsize=(15,7))
plt.scatter(df['VeryActiveMinutes'], df['Calories'])
plt.title('Very Active Minutes vs Calories')
plt.xlabel('Very Active Minutes')
plt.ylabel('Calories')
plt.grid(True)
plt.show()

# %%
# Plot of Fairly Active Minutes to the Calories burned
plt.figure(figsize=(15,5))
plt.scatter(df['FairlyActiveMinutes'], df['Calories'])
plt.title('Fairly Active Minutes vs Calories')
plt.xlabel('Fairly Active Minutes')
plt.ylabel('Calories')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.scatter(df['SedentaryMinutes'], df['Calories'])
plt.title('Sedentary Minutes vs Calories')
plt.xlabel('Sedentary Minutes')
plt.ylabel('Calories')
plt.grid(True)
plt.show()

# %%
# Checking the column names in the dataset
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
# Average Minutes spent on different Activity Level over Date
activity_minutes= df.groupby(df['ActivityDate'])[['VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes',
                                                  'SedentaryMinutes']].mean()

plt.figure(figsize=(15,5))
activity_minutes.plot(kind='line')
plt.title('Average Minutes Spent in Different Activity Levels per Activity Date')
plt.xlabel('Activity Date')
plt.ylabel('Average Minutes')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['TotalDistance'], bins=30, color='green', alpha=0.7)
plt.title('Distribution of Total Distance')
plt.xlabel('Total Distance (in miles)')
plt.ylabel('Frequency')
plt.xticks(np.arange(df['TotalDistance'].min(), df['TotalDistance'].max() + 1, 1))  # Set tick locations with an interval gap of 1
plt.grid(True)
plt.show()

# %%
# The distribution of total distance values in the dataset
plt.figure(figsize=(10, 5))
plt.hist(df['TotalDistance'], bins=30, color='green', alpha=0.7)
plt.title('Distribution of Total Distance')
plt.xlabel('Total Distance (in miles)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Checking the column names in the dataset
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
# The trend of very active minutes over time
plt.figure(figsize=(15,5))
sns.lineplot(x=df['ActivityDate'], y=df['VeryActiveMinutes'])
plt.title('Very Active Minutes over Time')
plt.xlabel('Activity Date')
plt.xticks(rotation=45)
plt.ylabel('Very Active Minutes')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance',
#        'LoggedActivitiesDistance', 'VeryActiveDistance',
#        'ModeratelyActiveDistance', 'LightActiveDistance',
#        'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes',
#        'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories'],
#       dtype='object')

# %%
# Trend of Total Distance and Tracker Distance over Time
plt.figure(figsize=(15,5))
plt.plot(df.groupby(df['ActivityDate'])['TotalDistance'].mean(), label='Average Total Distance', color='red')
plt.plot(df.groupby(df['ActivityDate'])['TrackerDistance'].mean(), label='Average Tracker Distance', color='blue')
plt.title('Total Distance and Tracker Distance over time')
plt.xlabel('Activity Date')
plt.xticks(rotation=45)
plt.ylabel('Distance Covered (in miles)')
plt.grid(True)
plt.show()

# %%
# Calories burned according to the different Activity Levels
def categorize_activity(steps):
    if steps < 5000:
        return 'Sedentary'
    if 5000 <= steps < 10000:
        return 'Lightly Active'
    if 10000 <= steps < 15000:
        return 'Moderately Active'
    else:
        return 'Very Active'

df['ActivityLevel'] = df['TotalSteps'].apply(categorize_activity)

plt.figure(figsize=(10, 5))
df.boxplot(column='Calories', by='ActivityLevel', grid=True)
plt.title('Calories Burned by Activity Level')
plt.suptitle('')
plt.xlabel('Activity Level')
plt.ylabel('Calories Burned')
plt.show()

# %%
# To check the count in each level of activites
df['ActivityLevel'].value_counts()
# Out:
# Lightly Active       334
# Sedentary            303
# Moderately Active    236
# Very Active           67
# Name: ActivityLevel, dtype: int64

# %%
# Top 10 users with highest calories burned
check_user = df.groupby('Id').agg({'Calories':'mean'}).sort_values(by='Calories').head(10)

plt.figure(figsize=(15,7))
sns.barplot(x=check_user.index, y=check_user['Calories'], order=check_user.index)
plt.xlabel('User ID')
plt.ylabel('Average Calories')
plt.title('Top 10 Users with Highest average Calories burned')
plt.xticks(rotation=45)
plt.yticks(np.arange(0, check_user['Calories'].max() + 100, 100))  # Set y-axis ticks with a gap of 100 calories
plt.grid(axis='y')
plt.show()

# %%
# Top 10 users with highest step count
check_user = df.groupby('Id').agg({'TotalSteps':'mean'}).sort_values(by='TotalSteps').head(10)

plt.figure(figsize=(15,7))
sns.barplot(x=check_user.index, y=check_user['TotalSteps'], order=check_user.index)
plt.xlabel('User ID')
plt.ylabel('Average Total Steps')
plt.title('Top 10 Users with Highest Average Total Steps')
plt.xticks(rotation=45)
plt.yticks(np.arange(0, check_user['TotalSteps'].max() + 300, 300))  # Set y-axis ticks with a gap of 300 steps
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### To view the detailed analysis and insights from this notebook, please visit my blog:
